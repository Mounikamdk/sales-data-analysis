# %% [markdown]
# # Sales Data Analysis Project

# %%
import pandas as pd

print("My first real project")
# Out:
# My first real project

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv("sales_data.csv")

df
# Out:
#          Date Product Region  Sales
# 0  2024-01-01  Laptop    USA   1200
# 1  2024-01-02   Phone  India    800
# 2  2024-01-03  Tablet    USA    400
# 3  2024-01-04  Laptop  India   1500
# 4  2024-01-05   Phone    USA    700
# 5  2024-01-06  Tablet  India    300
# 6  2024-01-07  Laptop    USA   2000
# 7  2024-01-08   Phone  India    900

# %% [markdown]
# # Data Analysis

# %%
df.head()
# Out:
#          Date Product Region  Sales
# 0  2024-01-01  Laptop    USA   1200
# 1  2024-01-02   Phone  India    800
# 2  2024-01-03  Tablet    USA    400
# 3  2024-01-04  Laptop  India   1500
# 4  2024-01-05   Phone    USA    700

# %%
df.describe()
# Out:
#              Sales
# count     8.000000
# mean    975.000000
# std     570.087713
# min     300.000000
# 25%     625.000000
# 50%     850.000000
# 75%    1275.000000
# max    2000.000000

# %%
df["Sales"].sum()
# Out:
# np.int64(7800)

# %%
df.groupby("Product")["Sales"].sum()
# Out:
# Product
# Laptop    4700
# Phone     2400
# Tablet     700
# Name: Sales, dtype: int64

# %%
df.groupby("Region")["Sales"].sum()
# Out:
# Region
# India    3500
# USA      4300
# Name: Sales, dtype: int64

# %%
df.groupby("Product")["Sales"].sum().idxmax()
# Out:
# 'Laptop'

# %%
df.groupby("Product")["Sales"].sum().idxmin()
# Out:
# 'Tablet'

# %%
df.groupby("Region")["Sales"].sum().idxmax()
# Out:
# 'USA'

# %%
df["Sales"].mean()
# Out:
# np.float64(975.0)

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt

df.groupby("Product")["Sales"].sum().plot(kind="bar")

plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Sales")

plt.show()

# %%
df.groupby("Region")["Sales"].sum().plot(kind="bar")

plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")

plt.show()

# %%
sales_by_region = df.groupby("Region")["Sales"].sum()

sales_by_region.plot(kind="pie", autopct='%1.1f%%')
plt.title("Sales by Region")
plt.show()

# %% [markdown]
# # Advanced Analysis

# %%
df.groupby("Region")["Sales"].mean()
# Out:
# Region
# India     875.0
# USA      1075.0
# Name: Sales, dtype: float64

# %%
df.groupby(["Region", "Product"])["Sales"].sum()
# Out:
# Region  Product
# India   Laptop     1500
#         Phone      1700
#         Tablet      300
# USA     Laptop     3200
#         Phone       700
#         Tablet      400
# Name: Sales, dtype: int64

# %%
df.groupby(["Region", "Product"])["Sales"].sum().reset_index()
# Out:
#   Region Product  Sales
# 0  India  Laptop   1500
# 1  India   Phone   1700
# 2  India  Tablet    300
# 3    USA  Laptop   3200
# 4    USA   Phone    700
# 5    USA  Tablet    400

# %% [markdown]
# # Final Business Insight
#
# - Laptop is the top-performing product, contributing the highest revenue
# - Tablet has the lowest sales and may require marketing improvements
# - USA generates higher total sales compared to India
# - Sales patterns suggest focusing on high-performing products and regions to maximize revenue

# %% [markdown]
# # - Certain products perform differently across regions, indicating region-specific demand patterns

# %% [markdown]
# # Conclusion
#
# This project analyzes sales performance across products and regions using Python.
# The findings highlight key revenue drivers and opportunities for business growth.
# These insights can help in making data-driven decisions to improve sales strategy.
