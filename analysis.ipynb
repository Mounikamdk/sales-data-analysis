# %%
import pandas as pd

print("My first real project")
# Out:
# My first real project

# %%
import pandas as pd

df = pd.read_csv("sales_data.csv")

df
# Out:
#          Date Product Region  Sales
# 0  2024-01-01  Laptop    USA   1200
# 1  2024-01-02   Phone  India    800
# 2  2024-01-03  Tablet    USA    400
# 3  2024-01-04  Laptop  India   1500
# 4  2024-01-05   Phone    USA    700
# 5  2024-01-06  Tablet  India    300
# 6  2024-01-07  Laptop    USA   2000
# 7  2024-01-08   Phone  India    900

# %%
df.head()
# Out:
#          Date Product Region  Sales
# 0  2024-01-01  Laptop    USA   1200
# 1  2024-01-02   Phone  India    800
# 2  2024-01-03  Tablet    USA    400
# 3  2024-01-04  Laptop  India   1500
# 4  2024-01-05   Phone    USA    700

# %%
df.describe()
# Out:
#              Sales
# count     8.000000
# mean    975.000000
# std     570.087713
# min     300.000000
# 25%     625.000000
# 50%     850.000000
# 75%    1275.000000
# max    2000.000000

# %%
df["Sales"].sum()
# Out:
# np.int64(7800)

# %%
df.groupby("Product")["Sales"].sum()
# Out:
# Product
# Laptop    4700
# Phone     2400
# Tablet     700
# Name: Sales, dtype: int64

# %%
df.groupby("Region")["Sales"].sum()
# Out:
# Region
# India    3500
# USA      4300
# Name: Sales, dtype: int64

# %%
import matplotlib.pyplot as plt

df.groupby("Product")["Sales"].sum().plot(kind="bar")

plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Sales")

plt.show()

# %%
df.groupby("Region")["Sales"].sum().plot(kind="bar")

plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")

plt.show()

# %%
df.groupby("Product")["Sales"].sum().idxmax()
# Out:
# 'Laptop'

# %%
df.groupby("Product")["Sales"].sum().idxmin()
# Out:
# 'Tablet'

# %%
df.groupby("Region")["Sales"].sum().idxmax()
# Out:
# 'USA'

# %% [markdown]
# ## Insights
#
# - Laptop has highest sales
# - Tablet has lowest sales
# - USA performs better than India
# - Total sales is strong for laptops
#
# Conclusion:
# Focus more on laptops to increase revenue

# %%
df["Sales"].mean()
# Out:
# np.float64(975.0)

# %% [markdown]
# # Business Insights
#
# ### 1. Top Performing Product
# - Laptop has the highest total sales
# - This means customers prefer laptops the most
#
# ### 2. Lowest Performing Product
# - Tablet has the lowest sales
# - This product may need improvement or promotion
#
# ### 3. Regional Performance
# - USA has higher sales compared to India
# - Focus on high-performing regions
#
# ### 4. Overall Sales
# - Total sales is strong and consistent
# - Business is performing well overall
#
# ## Conclusion
# - Focus on selling more laptops
# - Improve marketing for tablets
# - Expand in high-performing regions
